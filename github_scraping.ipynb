# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome('./chromedriver.exe')

# %%
browser.get('https://github.com/login')

# %% [markdown]
# id : input#login_field, password : input#password, button : a.libel-link

# %%
browser.find_elements_by_css_selector('input#login_field')[0].send_keys('webdessin@naver.com')

# %%
browser.find_elements_by_css_selector('input#password')[0].send_keys('slrclass55!')
browser.find_elements_by_css_selector('input[type="submit"]')[0].click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="4728b54bec34449ca7b79627014bb424", element="e91372a2-029d-4691-a8c4-5636573231a8")>>

# %%
browser.get('https://github.com/webdessin/class_webscraping')

# %%
from bs4 import BeautifulSoup

# %%
html = BeautifulSoup(browser.page_source, 'html.parser')
html
# Out:
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en"><head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-55f23fa01c49298e3e64d776e2f4cf8b.css" integrity="sha512-VfI/oBxJKY4+ZNd24vTPiyumBP7aGW4fepRsD/fUTuz8Ebw8WLpgvNkCNjj8+YRFbtZUyBfJ9UTEzXippSqvaA==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/behaviors-4011b07e193ebe02a153471dd1fbb252.css" integrity="sha512-QBGwfhk+vgKhU0cd0fuyUkl8IOVe2ZRe6xHaAr2nAVqmcLmZ6jTJHONlhBDcSIC5i5rNT7CKK0Ltccp7iqE7iQ==" media="all" rel="stylesheet"/>
# ...

# %%
tags = html.select('div[role="row"].Box-row')
type(tags), len(tags)
# Out:
# (bs4.element.ResultSet, 15)

# %%
contents = []

# %%
for tag in html:
    title = tag.text.strip()
    commit = tag.text.strip()
    desc = tag.text.strip()
    content = [title, commit, desc]
    contents.append(content)

# %%
# Out:
# [['GitHub - webdessin/class_webscraping\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n                Sign\xa0up\n              \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                    Why GitHub?\n                    \n\n\n\n\nFeatures →\n\nMobile →\nActions →\nCodespaces →\nPackages →\nSecurity →\nCode review →\nIssues →\nIntegrations →\n\n\nGitHub Sponsors →\nCustomer stories→\n\n\n\n\n\nTeam\n\n\nEnterprise\n\n\n\n\n                    Explore\n                    \n\n\n\n\n\nExplore GitHub →\n\nLearn and contribute\n\nTopics →\nCollections →\nTrending →\nLearning Lab →\nOpen source guides →\n\nConnect with others\n\nThe ReadME Project →\nEvents →\nCommunity forum →\nGitHub Education →\nGitHub Stars program →\n\n\n\n\n\nMarketplace\n\n\n\n\n                    Pricing\n                    \n\n\n\n\nPlans →\n\nCompare plans →\nContact Sales →\n\n\nEducation →\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\
# ...

# %%
import pandas

# %%
pd = pandas.DataFrame=
