# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome('./chromedriver.exe')

# %%
browser.get('http://ticket.interpark.com/contents/Ranking')

# %%
html = browser.page_source
html
# Out:
# '<html><head><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/ec.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5QCJFLB"></script>\n    \n    <meta charset="euc-kr">\n    <meta http-equiv="Content-Script-Type" content="text/javascript">\n    <meta http-equiv="Content-Style-Type" content="text/css">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <title>티켓 랭킹- 인터파크</title>\n    <meta name="description" content="지금 가장 인기있는 티켓은?오늘 당신을 기다리는 공연, 전시, 레저, 스포츠까지 인터파크에서 한번에 만나보세요. ">\n    <meta name="keywords" content="뮤지컬, 콘서트, 연극, 클래식, 무용, 스포츠, 레저, 전시, 행사, 아동, 가족, 프로야구, 프로축구, 프로농구, 프로배구, 예매">\n    <!-- jquery templ -->\n    <script src="https://connect.facebook.net/signals/config/1368896999886986?v=2.9.42&amp;r=stable" async=""></script><script src="https://connect.facebook.net/signals/config/135611513637810?v=2.9.42&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" src="//ticket.interpark.com/Lib/js/jquery-1.11.2.min.js"></script>\n    <script type="text/javascript" src="//ticket.interpark.com/Lib/Templates/JsRender/jsrender.min.js"></script>\n    <script type="text/javascript" src="//ticket.interpark.com/Lib/Templates/JsRender/render.js?v=20150420"></script>\n    <script type="text/javascript" src="//ticket.interpark.com/Lib/Templates/JsRender/render_common.js?v=20150420"></script>\n\n    <script type="text/javascript" src="//ticket.interpark.com/Search/Auto/SearchAutoComplete.js" charset="euc-kr"></script>\n    <script type="text/javascript" src="//ticket.interpark.com/Lib/js/TicketMain.js"></script>\n    <script type="text/javascript" src="//ticket.interpark.com/Include/Mobile/TPMobile.js?20121206"></script>\n    <script type="text/javascript" src="//ticket.interpark.com/Lib/js/LocalWelcom.asp"></script>\n\n    <script type="text/javascript" src="//ticket.interpark.com/contents/Scripts/Common.js"></script>\n\n\n    <!-- CSS -->\n    <link rel="stylesheet" href="//ticketimage.interpark.com/TicketImage/uidev/desktop/styles/common/common.css">\n\n    \n    \n    <link rel="stylesheet" href="http://ticketimage.interpark.com/TicketImage/uidev/desktop/styles/pages/ranking/ranking_main.css">\n    <script type="text/javascript" src="http://ticketimage.interpark.com/TicketImage/2016/20160308_ranking/list/js/jquery.tinyscrollbar.min.js"></script>\n    <script type="text/javascript" src="http://ticketimage.interpark.com/TicketImage/2016/20160308_ranking/list/js/ranking_detail.js"></script>\n    <script type="text/javascript" src="http://ticket.interpark.com/Lib/Templates/JsRender/jsrender.min.js"></script>\n    <script src="/contents/Scripts/Ranking/Ranking.Common.js"></script>\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/adimg3.search/adpost/js/adpost_show_ads_v2.min.js"></script></head>\n\n\t<body>\n\t\n\t    <!-- 헤더 시작 -->\n        \n<!-- E: 지마켓 헤더 삽입 테스트 -->\n<!-- S: 최상단 홈 티켓바로가기 -->\n<script type="text/javascript" src="//ticket.interpark.com/Lib/js/base64.js?ver=201304"></script>\n<script type="text/javascript" src="//ticket.interpark.com/Lib/js/GatewayBar.js?ver=20190124" charset="euc-kr"></script>\t<div id="gateway_warp">\t\t<div id="gateway_con">\t\t\t<div class="gnbArea_top">\t\t\t\t<div class="bn_Center"></div>\t\t\t\t<div class="gnbArea_left">\t\t\t\t\t<ul>\t\t\t\t\t\t<li>\t\t\t\t\t\t\t<a class="btn_gnbHome" href="http://www.interpark.com/malls/index.html?gateTp=1&amp;tid1=main_gnb&amp;tid2=ci&amp;tid3=welcome&amp;tid4=welcome">\t\t\t\t\t\t\t\t<img src="http://ticketimage.interpark.com//TicketImage/2015/20150429_main/img/header/blank.png" alt="홈">\t\t\t\t\t\t\t</a>\t\t\t\t\t\t</li>\t\t\t\t\t\t<li>\t\t\t\t\t\t\t<a class="btn_gnbBook" href="http://book.interpark.com/bookPark/html/book.html?&amp;tid1=main_gnb&amp;tid2=left_top&amp;t ...

# %%
# prdName
# prdDuration
